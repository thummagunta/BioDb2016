# %%
def revcompl(dna):
    rev_compl = ""
    pair = {'A' : 'T', 'C' : 'G', 'G' : 'C', 'T' : 'A'}
    for c in dna[::-1]:
        rev_compl += pair[c]
    return rev_compl

dna = '...'


res = revcompl(dna)
print (res)
# Out:
# ...
